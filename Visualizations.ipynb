# %%
import pandas as pd
import matplotlib as plt
import pylab as py
import seaborn as sns

# %%
mastery = pd.read_csv("masteryTableV4.csv")
matches = pd.read_csv("matchesV8.csv")
players = pd.read_csv("playersV5.csv")

# %%
players.head()
# Out:
#    Unnamed: 0                                         summonerId summonerName  \
# 0           0  ppk_I7Z1HLy57h58X6rwYGacsVOyz51hd6_AHBjNkKrW9j...      TL Yeon
# 1           1   wq4Tbh7L6jUg5PhpiyVS485d9QoBUbvNsIPi1hHYHKdOT1ju         APA3
# 2           2    MGo9-pY-7yQs2dKfvjt7dlWRWzcNBit4O36T43Hm10Ajy2Q   cupcakes29
# 3           3    dQLrFLjQzdm7T-_Nsg1QF0mlwP52rmvEX68L-431sb3nS1M       Busio3
# 4           4  Vbsf8W74eMoaEJtOmd8lwfDkSxNFNu4FRS1wB_wpQ3SZoo...     agorinas
#
#    leaguePoints  wins  losses        rank  \
# 0          1025   160     129  Challenger
# 1           639   154     137  Challenger
# 2           799   337     308  Challenger
# 3          1111   220     178  Challenger
# 4           912   136     112  Challenger
#
#                                            accountId   winrate
# 0  ij111eCiB7YRMfpbXTtNCqWRRfKwgudj2228q2-1wZ8AFZ...  0.553633
# 1  bJFSWY0PUbaGnfBkYc2njp24XDgXgQqTH-2lkEf-o-xxw7...  0.529210
# 2    9ztzAQ46FRYfm98jJfcYwmkL6es2LLir2dWkevXd9aQ22-M  0.522481
# 3    Pfd1GjtYhZGqRfEaEpGy0n3lTlozWeZum_Eh6JQ_JLhNaWA  0.552764
# 4  XW-GvUqCXll3nmYspdY6PO0AAKZgULFpPLBT-8F3eE7J3J...  0.548387

# %%
mastery.head()
# Out:
#    Unnamed: 0                                         summonerId  championId  \
# 0           0  ppk_I7Z1HLy57h58X6rwYGacsVOyz51hd6_AHBjNkKrW9j...          81
# 1           1  ppk_I7Z1HLy57h58X6rwYGacsVOyz51hd6_AHBjNkKrW9j...         360
# 2           2  ppk_I7Z1HLy57h58X6rwYGacsVOyz51hd6_AHBjNkKrW9j...         523
# 3           3  ppk_I7Z1HLy57h58X6rwYGacsVOyz51hd6_AHBjNkKrW9j...         110
# 4           4  ppk_I7Z1HLy57h58X6rwYGacsVOyz51hd6_AHBjNkKrW9j...         145
#
#    championPoints championName
# 0           25331       Ezreal
# 1           23610       Samira
# 2           20555     Aphelios
# 3           17321        Varus
# 4           16268       Kai'Sa

# %%
alist = list(mastery['championName'])
adict = dict((x,alist.count(x)) for x in set(alist))
adict
# Out:
# {'Rumble': 749,
#  'Singed': 636,
#  'Malzahar': 616,
#  'Orianna': 769,
#  'Urgot': 622,
#  'Nautilus': 757,
#  'Teemo': 673,
#  'Soraka': 787,
#  'Vayne': 848,
#  'Xin Zhao': 712,
#  'Zac': 671,
#  'Azir': 693,
#  'Zyra': 572,
#  'Jayce': 755,
#  'Graves': 860,
#  'Nocturne': 705,
#  'Lulu': 806,
#  'Viego': 575,
#  'Miss Fortune': 815,
#  'Zoe': 707,
#  'Dr. Mundo': 729,
#  'Kled': 569,
#  "Rek'Sai": 647,
#  'Yuumi': 619,
#  "Cho'Gath": 770,
#  'Diana': 724,
#  'Fiddlesticks': 724,
#  'Malphite': 816,
#  'Karthus': 819,
#  'Blitzcrank': 796,
#  'Kayle': 774,
#  'Ivern': 573,
#  'Wukong': 749,
#  'Leona': 738,
#  'Rell': 355,
#  'Braum': 658,
#  'Xerath': 699,
#  'Lillia': 658,
#  'Nasus': 685,
#  'Kennen': 711,
#  'Udyr': 650,
#  'Camille': 762,
#  'Sett': 725,
#  'Olaf': 723,
#  'Lucian': 915,
#  'Viktor': 728,
#  'Nunu & Willump': 764,
#  'Jinx': 821,
#  'Zilean': 698,
#  'Akali': 833,
#  'LeBlanc': 793,
#  'Cassiopeia': 741,
#  'Kayn': 748,
#  'Ashe': 865,
#  'Talon': 656,
#  'Poppy': 751,
#  'Neeko': 624,
#  'Tryndamere': 669,
#  'Ahri': 753,
#  'Fizz': 761,
#  'Morgana': 861,
#  'Aphelios': 616,
#  'Senna': 712,
#  'Aurelion Sol': 579,
#  'Master Yi': 795,
#  'Riven': 790,
#  'Shyvana': 660,
#  'Twitch': 815,
#  'Seraphine': 559,
#  'Gangplank': 743,
#  'Gragas': 820,
#  'Evelynn': 698,
#  "Vel'Koz": 703,
#  'Rengar': 703,
#  'Ornn': 652,
#  'Lissandra': 637,
#  'Jhin': 860,
#  'Bard': 710,
#  'Vi': 602,
#  'Tristana': 891,
#  'Shen': 668,
#  'Taliyah': 706,
#  'Irelia': 848,
#  'Lee Sin': 905,
#  'Elise': 699,
#  'Taric': 592,
#  'Veigar': 805,
#  'Kindred': 740,
#  'Maokai': 742,
#  'Rakan': 670,
#  'Brand': 774,
#  'Sylas': 802,
#  'Karma': 802,
#  'Skarner': 537,
#  'Nami': 602,
#  'Ziggs': 693,
#  'Mordekaiser': 738,
#  'Kassadin': 749,
#  'Yone': 676,
#  'Jax': 804,
#  'Tahm Kench': 632,
#  'Rammus': 643,
#  'Trundle': 623,
#  'Quinn': 654,
#  'Amumu': 723,
#  'Volibear': 709,
#  'Corki': 718,
#  'Renekton': 745,
#  "Kai'Sa": 799,
#  'Varus': 830,
#  'Warwick': 661,
#  'Zed': 838,
#  'Kalista': 755,
#  'Aatrox': 800,
#  'Samira': 586,
#  'Gnar': 717,
#  'Alistar': 783,
#  'Yasuo': 827,
#  'Garen': 747,
#  'Thresh': 801,
#  'Heimerdinger': 638,
#  'Syndra': 740,
#  'Nidalee': 816,
#  'Darius': 743,
#  'Sion': 720,
#  'Anivia': 656,
#  'Sejuani': 595,
#  "Kha'Zix": 804,
#  'Janna': 736,
#  'Pyke': 788,
#  'Sivir': 851,
#  'Qiyana': 655,
#  'Fiora': 774,
#  'Yorick': 473,
#  'Lux': 795,
#  'Annie': 788,
#  'Pantheon': 805,
#  'Ekko': 860,
#  'Draven': 763,
#  'Twisted Fate': 823,
#  'Illaoi': 553,
#  'Jarvan IV': 759,
#  'Gwen': 380,
#  'Ezreal': 920,
#  'Hecarim': 765,
#  'Galio': 740,
#  'Katarina': 752,
#  'Swain': 653,
#  'Vladimir': 809,
#  'Caitlyn': 835,
#  'Ryze': 860,
#  "Kog'Maw": 732,
#  'Shaco': 663,
#  'Sona': 671,
#  'Xayah': 785}

# %%
#swarmplot of players mastery of these specific champions
darius = mastery[mastery['championName'] == 'Darius']
leesin = mastery[mastery['championName'] == 'Lee Sin']
zed = mastery[mastery['championName'] == 'Zed']
lucian = mastery[mastery['championName'] == 'Lucian']
thresh = mastery[mastery['championName'] == 'Thresh']
popular = darius.append(leesin).append(zed).append(lucian).append(thresh)
#popular 
ax = sns.swarmplot(x="championPoints", y="championName", data=popular, hue = "championName") #sns.boxplot(list(lucian['championPoints']))
# Out:
# c:\users\devin\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 93.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\devin\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 90.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\devin\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 93.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\devin\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 92.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\devin\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 88.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#swarmplot of players mastery of these specific champions

Yorick = mastery[mastery['championName'] == 'Yorick']
Lillia = mastery[mastery['championName'] == 'Lillia']
Ryze = mastery[mastery['championName'] == 'Ryze']
Xayah = mastery[mastery['championName'] == 'Xayah']
Nami = mastery[mastery['championName'] == 'Nami']
unpopular = Yorick.append(Lillia).append(Ryze).append(Xayah).append(Nami)
#popular 
ax2 = sns.swarmplot(x="championPoints", y="championName", data=unpopular, hue = "championName") #sns.boxplot(list(lucian['championPoints']))
#ax2.set_xlim([0, 100000])
# Out:
# c:\users\devin\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 93.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\devin\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 95.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\devin\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 92.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\devin\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 89.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\devin\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 87.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import matplotlib.pyplot as plt
sns.scatterplot(data=players,x="wins",y="leaguePoints",hue='rank')
plt.xlim(0,800)
plt.ylim(0,1700)
# Out:
# (0.0, 1700.0)

# %%
#players['winrate'] = players['wins']/(players['wins']+players['losses'])
sns.scatterplot(data=players,x="winrate",y="leaguePoints",hue="rank")
plt.xlim(0.45,0.75)
plt.ylim(0,1700)
#players
# Out:
# (0.0, 1700.0)

# %%
players['wins'].corr(players['leaguePoints'])
players['winrate'].corr(players['leaguePoints'])
# Out:
# 0.16996310189108288

# %%
import numpy as np
np.mean(players['winrate'])
# Out:
# 0.5428186413307159

# %%
players.to_csv("playersV4.csv")

# %%
#p2
