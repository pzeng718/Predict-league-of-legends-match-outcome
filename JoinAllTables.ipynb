# %%
import pandas as pd
import numpy as np
#import matplotlib as plt
#import pylab as py
#import seaborn as sns

# %%
p2 = pd.read_csv("playersV5.csv")
matches2 = pd.read_csv("matchesV7.csv")
#mastery2 = pd.read_csv("masteryTableV2.csv")
mastery = pd.read_csv("masteryTableV4.csv")
#matches = pd.read_csv("matches.csv")
#players = pd.read_csv("players.csv")

# %%
finalTable = matches2

finalTable.head()
# Out:
#    Unnamed: 0      gameId TeamTwoWin  Team1P1  Team1P2  Team1P3  Team1P4  \
# 0           0  3911150350       Fail       18      235       76      223
# 1           0  3911074019       Fail      360       61       14      111
# 2           0  3910663845       Fail      201      202      143      234
# 3           0  3908250596        Win      412       64        8      222
# 4           0  3908205817        Win      110      412      517      107
#
#    Team1P5  Team2P1  Team2P2  ...  \
# 0       64       68      429  ...
# 1       60      145        7  ...
# 2       35      360       79  ...
# 3        5       81       68  ...
# 4      518       18       68  ...
#
#                                           Team1P1SID  \
# 0       gGiH6hAzcy34gt3yIbk-LRl7oWOUPLvN1Dfk0Ibo3YFr
# 1  ppk_I7Z1HLy57h58X6rwYGacsVOyz51hd6_AHBjNkKrW9j...
# 2  2978Fb3zGwrn2FDvqahHGugfoWpadoEVtPZAsLJItrrMH3...
# 3   C3KnDmMI-nID7Yjc1V1qwH2sm1tmoIq0tLGgubaOV1CRHXXG
# 4  ppk_I7Z1HLy57h58X6rwYGacsVOyz51hd6_AHBjNkKrW9j...
#
#                                           Team1P2SID  \
# 0  ft6xHf_s_12OarY8Ai4iGtgL2_CBb2fqXSicUW5746bdhE...
# 1    8RfUD9cxN-dLQLxL32H5lDDf9tlfcqUOFs8iAxZGYcrp-sM
# 2    Od9ZC5Z9yDJj7_1Vb9pwX_Xnzfp_G7C7FR7cOQNS6rW8iAg
# 3    q3hWqt5srh4HmLbWRnAspzqSdKw5mlb5IV9xYNlJrd37sz8
# 4    9BsFJYqRsyLI-g0ibJ-wRP5NuiHPBSE1cY8gWjrfQ6F-BTk
#
#                                          Team1P3SID  \
# 0   D_oa4tTWHTwiy8GSX7Ch7XPwFbz61h34N3NGGwEMJMvW1ng
# 1   E7KWnTRa3pAS96yBlTBsB05RELOyoAyA06u4cSPGFQWnfR0
# 2   oCK2sCothODw-YavRYK6iGfZrMreEz-PONtNubiPUHQClsk
# 3  Shw6hmhcLfTbs9qdJffVK6jdBUF8F6vtq5r0DRc3rzOUW-vF
# 4  Shw6hmhcLfTbs9qdJffVK6jdBUF8F6vtq5r0DRc3rzOUW-vF
#
#                                          Team1P4SID  \
# 0   4s7DdZbcZWd_a6QL-HUhMl1Z9NwMGL_6R3fPjxEjhUd-dvU
# 1   4s7DdZbcZWd_a6QL-HUhMl1Z9NwMGL_6R3fPjxEjhUd-dvU
# 2   NEuYrQvx7NJBKR81S4FxbDD7XAinbcEa4gNDxPi2pc5JqiI
# 3  ZFGsI5tsvVGThftY2WgHU4UCh-nhryIO9pN8wZOFIRW0eV0V
# 4   QMlnbLzP27xd_KNsR2gNwU7iqfHTV8jl2rvwCOfRxN7dIQo
# 3   JRTPYasCNYlGr4tywfcy2yF5ei1smue0p5THs78rr3XkTjbI
# 4    7FrDnT8j9iNnIuKx8tjCmYC8dd1mWFB24MTAy58FFtmhtg4
#
# [5 rows x 33 columns]

# %%
list(finalTable['Team2P1SID'])[0]
p2.head()
# Out:
#    Unnamed: 0                                         summonerId summonerName  \
# 0           0  ppk_I7Z1HLy57h58X6rwYGacsVOyz51hd6_AHBjNkKrW9j...      TL Yeon
# 1           1   wq4Tbh7L6jUg5PhpiyVS485d9QoBUbvNsIPi1hHYHKdOT1ju         APA3
# 2           2    MGo9-pY-7yQs2dKfvjt7dlWRWzcNBit4O36T43Hm10Ajy2Q   cupcakes29
# 3           3    dQLrFLjQzdm7T-_Nsg1QF0mlwP52rmvEX68L-431sb3nS1M       Busio3
# 4           4  Vbsf8W74eMoaEJtOmd8lwfDkSxNFNu4FRS1wB_wpQ3SZoo...     agorinas
#
#    leaguePoints  wins  losses        rank  \
# 0          1025   160     129  Challenger
# 1           639   154     137  Challenger
# 2           799   337     308  Challenger
# 3          1111   220     178  Challenger
# 4           912   136     112  Challenger
#
#                                            accountId   winrate
# 0  ij111eCiB7YRMfpbXTtNCqWRRfKwgudj2228q2-1wZ8AFZ...  0.553633
# 1  bJFSWY0PUbaGnfBkYc2njp24XDgXgQqTH-2lkEf-o-xxw7...  0.529210
# 2    9ztzAQ46FRYfm98jJfcYwmkL6es2LLir2dWkevXd9aQ22-M  0.522481
# 3    Pfd1GjtYhZGqRfEaEpGy0n3lTlozWeZum_Eh6JQ_JLhNaWA  0.552764
# 4  XW-GvUqCXll3nmYspdY6PO0AAKZgULFpPLBT-8F3eE7J3J...  0.548387

# %%
finalTable2 = finalTable.head()
counter = 0
for index, row in finalTable2.iterrows():
    finalTable2["T1P1LP"] = p2[p2["summonerId"] == finalTable["Team1P1SID"][counter]]["leaguePoints"]
    counter = counter + 1
#finalTable2["T1P1LP"] = p2[p2["summonerId"] == finalTable["Team1P1SID"][5]]["leaguePoints"]
    
'''
try:
    finalTable2["T1P1LeaguePoints"] = p2[p2["summonerId"] == finalTable["Team1P1SID"]]["leaguePoints"]
except ValueError:
    pass
'''    
finalTable2
# Out:
# <ipython-input-27-b776681cb81c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finalTable2["T1P1LP"] = p2[p2["summonerId"] == finalTable["Team1P1SID"][counter]]["leaguePoints"]
#    Unnamed: 0      gameId TeamTwoWin  Team1P1  Team1P2  Team1P3  Team1P4  \
# 0           0  3882085921       Fail       96       29      360        6
# 1           0  3882103783        Win      876      875      427       68
# 2           0  3882119789       Fail      131       18      432      517
# 3           0  3882045523        Win       25       16       38      119
# 4           0  3882023571        Win       89      115       24      360
#
#    Team1P5  Team2P1  Team2P2  ...  \
# 0      112      203      157  ...
# 1      432      555       53  ...
# 2      106      526      120  ...
# 3       64      517       62  ...
# 4       30       25      105  ...
#
#                                          Team1P2SID  \
# 0  PBUwkmJAZcX8gK7GLYQakQ8JNrYr2lu84rf59H5EC06E2Wg2
#
#                                          Team2P3SID  \
# 0  N5G25tgJbExcn-ZC6bvKNMz8vXq8N63BEv765WXnIfa50a61
# 1   a6IN6VX7OhoSrTO9XfYLkiq4IX4qQBOZdb1TkWMS6vj31rE
# 2   Pqz90M3Ow9jRyIhwYh6eLLCYvS9H5R67M48kzjzTw-D-7Pg
# 3   4dy_R8Bsn5K5i6N_rCXWRid2oVhOay9DChrziGdXsUgiLXs
# 4   6FIk2Gg67OkliUmVH-VR36HXiKwR9sm-X4k1oVeNmhO2c7Y
#
#                                          Team2P4SID  \
# 0  auKoUXBD7TSW06WTZIwFWkCEwnUmwV_z4q2Zf8dwOFYtRQ50
# 1   tT9AGjdAXWQgUypwrEUPGEIfR61NMBppYsECQQZMwlT-oO0
# 2   _XcNxsvPLFAVgbmUQxHp6U0EkBLxvN4_7zCJWjr7MdNarzQ
# 3  URMfCZVNNEylDxyxn8FsTRWPmH0cPtnHMgcybj_CMYMic4C3
# 4   xkvhucojMbpNKoDrbeHnPbarQm8vEWMa457hCpXGfANEIVk
#
#                                          Team2P5SID T1P1LP
# 0   Eb5Ia26ijVa_OKlnb8XghTayR5B0EVIxK0NlfPVWln60-Po    NaN
# 1   RxhN_jtdO5757rncs6EM3xVju3XlvTx9qVMKTDD0JkMt0A8    NaN
# 2  KX9Oq72Hs_ZdaqpPoailTdH42aWx8r9m2GVzF_46IzQVYT4X    NaN
# 3   CQgRwPicbM-ukSR6QcPOgQWGXm2Hmhbb0mzSr7gD4kCG2eM    NaN
# 4   TteAC3Wv_Sx2JmMd7rzseqOM_l1E6feZNWlhqznjrv670iQ    NaN
#
# [5 rows x 24 columns]

# %%
finalTable2 = pd.read_csv("matchesV7.csv")

# %%
p2.head()
# Out:
#    Unnamed: 0                                         summonerId summonerName  \
# 0           0  ppk_I7Z1HLy57h58X6rwYGacsVOyz51hd6_AHBjNkKrW9j...      TL Yeon
# 1           1   wq4Tbh7L6jUg5PhpiyVS485d9QoBUbvNsIPi1hHYHKdOT1ju         APA3
# 2           2    MGo9-pY-7yQs2dKfvjt7dlWRWzcNBit4O36T43Hm10Ajy2Q   cupcakes29
# 3           3    dQLrFLjQzdm7T-_Nsg1QF0mlwP52rmvEX68L-431sb3nS1M       Busio3
# 4           4  Vbsf8W74eMoaEJtOmd8lwfDkSxNFNu4FRS1wB_wpQ3SZoo...     agorinas
#
#    leaguePoints  wins  losses        rank  \
# 0          1025   160     129  Challenger
# 1           639   154     137  Challenger
# 2           799   337     308  Challenger
# 3          1111   220     178  Challenger
# 4           912   136     112  Challenger
#
#                                            accountId   winrate
# 0  ij111eCiB7YRMfpbXTtNCqWRRfKwgudj2228q2-1wZ8AFZ...  0.553633
# 1  bJFSWY0PUbaGnfBkYc2njp24XDgXgQqTH-2lkEf-o-xxw7...  0.529210
# 2    9ztzAQ46FRYfm98jJfcYwmkL6es2LLir2dWkevXd9aQ22-M  0.522481
# 3    Pfd1GjtYhZGqRfEaEpGy0n3lTlozWeZum_Eh6JQ_JLhNaWA  0.552764
# 4  XW-GvUqCXll3nmYspdY6PO0AAKZgULFpPLBT-8F3eE7J3J...  0.548387

# %%
int(p2.loc[p2["summonerId"] == "TzZVECncJS4jMEZZgif9PBP81-8RP_ADx2Z4_VJ5b2Sz5Yk"]["leaguePoints"])
# Out:
# 1113

# %%
T1P1SID = finalTable2["Team1P1SID"].to_list()
T1P2SID = finalTable2["Team1P2SID"].to_list()
T1P3SID = finalTable2["Team1P3SID"].to_list()
T1P4SID = finalTable2["Team1P4SID"].to_list()
T1P5SID = finalTable2["Team1P5SID"].to_list()
T2P1SID = finalTable2["Team2P1SID"].to_list()
T2P2SID = finalTable2["Team2P2SID"].to_list()
T2P3SID = finalTable2["Team2P3SID"].to_list()
T2P4SID = finalTable2["Team2P4SID"].to_list()
T2P5SID = finalTable2["Team2P5SID"].to_list()

lp1,lp2,lp3,lp4,lp5,lp6,lp7,lp8,lp9,lp10 = [],[],[],[],[],[],[],[],[],[]
#lp11,lp12,lp13,lp14,lp15,lp16,lp17,lp18,lp19,lp20 = [],[],[],[],[],[],[],[],[],[]
wr1,wr2,wr3,wr4,wr5,wr6,wr7,wr8,wr9,wr10 = [],[],[],[],[],[],[],[],[],[]

for sid in T1P1SID:
    try:
        #lp1.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        #print(int(p2.loc[p2["summonerId"] == sid]["championPoints"]))
        #print(p2.loc[p2["summonerId"] == sid]["leaguePoints"])
        lp1.append(int(p2.loc[p2["summonerId"] == sid]["leaguePoints"]))
    except TypeError:
        lp1.append(200)
        
for sid in T1P2SID:
    try:
        #lp2.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        lp2.append(int(p2.loc[p2["summonerId"] == sid]["leaguePoints"]))
    except TypeError:
        lp2.append(200)
        
for sid in T1P3SID:
    try:
        #lp3.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        lp3.append(int(p2.loc[p2["summonerId"] == sid]["leaguePoints"]))
    except TypeError:
        lp3.append(200)
        
for sid in T1P4SID:
    try:
        #lp4.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        lp4.append(int(p2.loc[p2["summonerId"] == sid]["leaguePoints"]))
    except TypeError:
        lp4.append(200)
        
for sid in T1P5SID:
    try:
        #lp5.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        lp5.append(int(p2.loc[p2["summonerId"] == sid]["leaguePoints"]))
    except TypeError:
        lp5.append(200)

        
        
        
for sid in T2P1SID:
    try:
        #lp6.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        lp6.append(int(p2.loc[p2["summonerId"] == sid]["leaguePoints"]))
    except TypeError:
        lp6.append(200)
        
for sid in T2P2SID:
    try:
        #lp7.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        lp7.append(int(p2.loc[p2["summonerId"] == sid]["leaguePoints"]))
    except TypeError:
        lp7.append(200)

for sid in T2P3SID:
    try:
        #lp8.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        lp8.append(int(p2.loc[p2["summonerId"] == sid]["leaguePoints"]))
    except TypeError:
        lp8.append(200)

for sid in T2P4SID:
    try:
        #lp9.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        lp9.append(int(p2.loc[p2["summonerId"] == sid]["leaguePoints"]))
    except TypeError:
        lp9.append(200)

for sid in T2P5SID:
    try:
        #lp10.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        lp10.append(int(p2.loc[p2["summonerId"] == sid]["leaguePoints"]))
    except TypeError:
        lp10.append(200)
        
        
finalTable2["T1P1LP"] = lp1
finalTable2["T1P2LP"] = lp2
finalTable2["T1P3LP"] = lp3
finalTable2["T1P4LP"] = lp4
finalTable2["T1P5LP"] = lp5
finalTable2["T2P1LP"] = lp6
finalTable2["T2P2LP"] = lp7
finalTable2["T2P3LP"] = lp8
finalTable2["T2P4LP"] = lp9
finalTable2["T2P5LP"] = lp10
'''
finalTable2["T1P1LP1"] = lp11
finalTable2["T1P2LP1"] = lp12
finalTable2["T1P3LP1"] = lp13
finalTable2["T1P4LP1"] = lp14
finalTable2["T1P5LP1"] = lp15
finalTable2["T2P1LP1"] = lp16
finalTable2["T2P2LP1"] = lp17
finalTable2["T2P3LP1"] = lp18
finalTable2["T2P4LP1"] = lp19
finalTable2["T2P5LP1"] = lp20
'''
finalTable2
# Out:
#       Unnamed: 0      gameId TeamTwoWin  Team1P1  Team1P2  Team1P3  Team1P4  \
# 0              0  3911150350       Fail       18      235       76      223
# 1              0  3911074019       Fail      360       61       14      111
# 2              0  3910663845       Fail      201      202      143      234
# 3              0  3908250596        Win      412       64        8      222
# 4              0  3908205817        Win      110      412      517      107
# ...          ...         ...        ...      ...      ...      ...      ...
# 5601         858  3869422723        Win       68      157      114       79
# 5602         859  3869388709        Win       35       13       50       89
# 5603         860  3869413807        Win      107       30      432       92
# 5604         861  3868218442        Win      498       39       60      234
# 5605         862  3868211542       Fail       26       64       84      126
#
#       Team1P5  Team2P1  Team2P2  ...  T1P1LP  T1P2LP  T1P3LP T1P4LP T1P5LP  \
# 0          64       68      429  ...     510     394    1159   1018   1053
# 1          60      145        7  ...    1025    1331     817   1018    711
# 2          35      360       79  ...    1140     200     200    584    477
# 3           5       81       68  ...    1576     718     632    813   1025
# 4         518       18       68  ...    1025     965     632    681    740
# ...       ...      ...      ...  ...     ...     ...     ...    ...    ...
# 5601        9       67       50  ...     200     700     774    855    621
# 5602       39      110      432  ...     522     678    1139    566    353
# 5603       29       25       53  ...     392     200     713    774    386
# 5604       79      777       50  ...    1109     353     623   1132    574
# 5605       15      234       50  ...     791    1132    1109    854    658
#
#      T2P1LP T2P2LP T2P3LP T2P4LP T2P5LP
# 0      1197   1025    796   1016    200
# 1       349    200    200   1576    200
# 2      1025    413    454    771    461
# 3       960   1401    707    552   1463
# 4       938   1623    960    492    708
# ...     ...    ...    ...    ...    ...
# 5601   1109   1139   1043    668    713
# 5602    622    713    668    774   1043
# 5603    684    716    353   1139    678
# 5604    700   1139    908    855    691
# 5605    200   1139    200    700   1068
#
# [5606 rows x 43 columns]

# %%
wr1,wr2,wr3,wr4,wr5,wr6,wr7,wr8,wr9,wr10 = [],[],[],[],[],[],[],[],[],[]

for sid in T1P1SID:
    try:
        wr1.append(float(p2.loc[p2["summonerId"] == sid]["winrate"]))
    except TypeError:
        wr1.append(0.544)
        
for sid in T1P2SID:
    try:
        #lp2.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        wr2.append(float(p2.loc[p2["summonerId"] == sid]["winrate"]))
    except TypeError:
        wr2.append(0.544)
        
for sid in T1P3SID:
    try:
        #lp3.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        wr3.append(float(p2.loc[p2["summonerId"] == sid]["winrate"]))
    except TypeError:
        wr3.append(0.544)
        
for sid in T1P4SID:
    try:
        #lp4.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        wr4.append(float(p2.loc[p2["summonerId"] == sid]["winrate"]))
    except TypeError:
        wr4.append(0.544)
        
for sid in T1P5SID:
    try:
        #lp5.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        wr5.append(float(p2.loc[p2["summonerId"] == sid]["winrate"]))
    except TypeError:
        wr5.append(0.544)

        
        
        
for sid in T2P1SID:
    try:
        #lp6.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        wr6.append(float(p2.loc[p2["summonerId"] == sid]["winrate"]))
    except TypeError:
        wr6.append(0.544)
        
for sid in T2P2SID:
    try:
        #lp7.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        wr7.append(float(p2.loc[p2["summonerId"] == sid]["winrate"]))
    except TypeError:
        wr7.append(0.544)

for sid in T2P3SID:
    try:
        #lp8.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        wr8.append(float(p2.loc[p2["summonerId"] == sid]["winrate"]))
    except TypeError:
        wr8.append(0.544)

for sid in T2P4SID:
    try:
        #lp9.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        wr9.append(float(p2.loc[p2["summonerId"] == sid]["winrate"]))
    except TypeError:
        wr9.append(0.544)

for sid in T2P5SID:
    try:
        #lp10.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        wr10.append(float(p2.loc[p2["summonerId"] == sid]["winrate"]))
    except TypeError:
        wr10.append(0.544)
        
        
finalTable2["T1P1WR"] = wr1
finalTable2["T1P2WR"] = wr2
finalTable2["T1P3WR"] = wr3
finalTable2["T1P4WR"] = wr4
finalTable2["T1P5WR"] = wr5
finalTable2["T2P1WR"] = wr6
finalTable2["T2P2WR"] = wr7
finalTable2["T2P3WR"] = wr8
finalTable2["T2P4WR"] = wr9
finalTable2["T2P5WR"] = wr10

# %%
finalTable2.shape
# Out:
# (5606, 62)

# %%
#Works
p2[p2["summonerId"] == "auKoUXBD7TSW06WTZIwFWkCEwnUmwV_z4q2Zf8dwOFYtRQ50"]["leaguePoints"]
# Out:
# 1    504
# Name: leaguePoints, dtype: int64

# %%
T1P1CID = finalTable2["Team1P1"].to_list()
T1P2CID = finalTable2["Team1P2"].to_list()
T1P3CID = finalTable2["Team1P3"].to_list()
T1P4CID = finalTable2["Team1P4"].to_list()
T1P5CID = finalTable2["Team1P5"].to_list()
T2P1CID = finalTable2["Team2P1"].to_list()
T2P2CID = finalTable2["Team2P2"].to_list()
T2P3CID = finalTable2["Team2P3"].to_list()
T2P4CID = finalTable2["Team2P4"].to_list()
T2P5CID = finalTable2["Team2P5"].to_list()


cm1,cm2,cm3,cm4,cm5,cm6,cm7,cm8,cm9,cm10 = [],[],[],[],[],[],[],[],[],[]

counter = 0
for sid in T1P1SID:
    try:
        cm1.append(int(mastery.loc[(mastery["championId"] == T1P1CID[counter]) & (mastery["summonerId"] == sid)]["championPoints"]))
    except KeyError:
        cm1.append(0)
    except TypeError:
        cm1.append(1000)
    counter = counter + 1
    
counter = 0
for sid in T1P2SID:
    try:
        cm2.append(int(mastery.loc[(mastery["championId"] == T1P2CID[counter]) & (mastery["summonerId"] == sid)]["championPoints"]))
    except TypeError:
        cm2.append(1000)
    counter = counter + 1
    
counter = 0        
for sid in T1P3SID:
    try:
        cm3.append(int(mastery.loc[(mastery["championId"] == T1P3CID[counter]) & (mastery["summonerId"] == sid)]["championPoints"]))
    except TypeError:
        cm3.append(1000)
    counter = counter + 1

counter = 0
for sid in T1P4SID:
    try:
        cm4.append(int(mastery.loc[(mastery["championId"] == T1P4CID[counter]) & (mastery["summonerId"] == sid)]["championPoints"]))
    except TypeError:
        cm4.append(1000)
    counter = counter + 1
        
counter = 0
for sid in T1P5SID:
    try:
        cm5.append(int(mastery.loc[(mastery["championId"] == T1P5CID[counter]) & (mastery["summonerId"] == sid)]["championPoints"]))
    except TypeError:
        cm5.append(1000)
    counter = counter + 1

        
        
counter = 0        
for sid in T2P1SID:
    try:
        cm6.append(int(mastery.loc[(mastery["championId"] == T2P1CID[counter]) & \
                                   (mastery["summonerId"] == sid)]["championPoints"]))
    except TypeError:
        cm6.append(1000)
    counter = counter + 1
    
counter = 0        
for sid in T2P2SID:
    try:
        cm7.append(int(mastery.loc[(mastery["championId"] == T2P2CID[counter]) & \
                                   (mastery["summonerId"] == sid)]["championPoints"]))
    except TypeError:
        cm7.append(1000)
    counter = counter + 1
    
counter = 0
for sid in T2P3SID:
    try:
        cm8.append(int(mastery.loc[(mastery["championId"] == T2P3CID[counter]) & \
                                   (mastery["summonerId"] == sid)]["championPoints"]))
    except TypeError:
        cm8.append(1000)
    counter = counter + 1
    
counter = 0
for sid in T2P4SID:
    try:
        cm9.append(int(mastery.loc[(mastery["championId"] == T2P4CID[counter]) & \
                                   (mastery["summonerId"] == sid)]["championPoints"]))
    except TypeError:
        cm9.append(1000)
    counter = counter + 1
    
counter = 0
for sid in T2P5SID:
    try:
        cm10.append(int(mastery.loc[(mastery["championId"] == T2P5CID[counter]) & \
                                   (mastery["summonerId"] == sid)]["championPoints"]))
    except TypeError:
        cm10.append(1000)
    counter = counter + 1
        
        
finalTable2["T1P1CM"] = cm1
finalTable2["T1P2CM"] = cm2
finalTable2["T1P3CM"] = cm3
finalTable2["T1P4CM"] = cm4
finalTable2["T1P5CM"] = cm5
finalTable2["T2P1CM"] = cm6
finalTable2["T2P2CM"] = cm7
finalTable2["T2P3CM"] = cm8
finalTable2["T2P4CM"] = cm9
finalTable2["T2P5CM"] = cm10
finalTable2
# Out:
#           gameId TeamTwoWin  Team1P1  Team1P2  Team1P3  Team1P4  Team1P5  \
# 0     3911150350       Fail       18      235       76      223       64
# 1     3911074019       Fail      360       61       14      111       60
# 2     3910663845       Fail      201      202      143      234       35
# 3     3908250596        Win      412       64        8      222        5
# 4     3908205817        Win      110      412      517      107      518
# ...          ...        ...      ...      ...      ...      ...      ...
# 5601  3869422723        Win       68      157      114       79        9
# 5602  3869388709        Win       35       13       50       89       39
# 5603  3869413807        Win      107       30      432       92       29
# 5604  3868218442        Win      498       39       60      234       79
# 5605  3868211542       Fail       26       64       84      126       15
#
#       Team2P1  Team2P2  Team2P3  ...   T1P1CM  T1P2CM  T1P3CM  T1P4CM  \
# 0          68      429       50  ...     5915    8192  224771  100636
# 1         145        7      236  ...    23610   18935    9814  209543
# 2         360       79      107  ...     4353    1000    1000  268225
# 3          81       68      267  ...   261930   55663  520823  107431
# 4          18       68       14  ...    17321  445868   19981  573477
# ...       ...      ...      ...  ...      ...     ...     ...     ...
# 5601       67       50       59  ...     1000   36092  113167  120164
# 5602      110      432        3  ...   377601  103450  196609   50685
# 5603       25       53       39  ...   383163    1000   32824  775884
# 5604      777       50       12  ...   201284  587138   14578   15799
# 5605      234       50      887  ...  5734266   26759  219328   30577
#
#        T1P5CM  T2P1CM   T2P2CM  T2P3CM  T2P4CM   T2P5CM
# 0       14265    1781     1687   33408    3877     1000
# 1       83958    1693     1000    1000   88877     1000
# 2     1047618   23610   269517  401381  622033   180642
# 3         178  524667    20619   11672  604271   210840
# 4       10712  380700    44680   11321   68789    67313
# ...       ...     ...      ...     ...     ...      ...
# 5601   143102  169991   196609  101978   63145    32824
# 5602   587138   36971    32824  176860  775884    83392
# 5603     2253   36718  1382417  587138  196609  1913271
# 5604    10776   28841   196609  449007  213209    71289
# 5605   141178    1000   196609    1000   36092      406
#
# [5606 rows x 62 columns]

# %%
#WORKS
int(mastery.loc[(mastery["championId"] == 68) & (mastery["summonerId"] == "auKoUXBD7TSW06WTZIwFWkCEwnUmwV_z4q2Zf8dwOFYtRQ50")]["championPoints"])
# Out:
# 401

# %%
#Doesn't work yet
#np.where(mastery(mastery["championId"] == 68) & (mastery["summonerId"] == "auKoUXBD7TSW06WTZIwFWkCEwnUmwV_z4q2Zf8dwOFYtRQ50"))
len(finalTable2['T1P1WR'])
# Out:
# 5606

# %%
#del finalTable2['Unnamed: 0']

finalTable2.to_csv('CMWRLP1.csv')
