# %%
import pandas as pd
import numpy as np
#import matplotlib as plt
#import pylab as py
#import seaborn as sns

# %%
p2 = pd.read_csv("playersV3.csv")
matches2 = pd.read_csv("matchesV6.csv")
#mastery2 = pd.read_csv("masteryTableV2.csv")
mastery = pd.read_csv("masteryTableV3.csv")
#matches = pd.read_csv("matches.csv")
#players = pd.read_csv("players.csv")

# %%
#finalTable = matches2

finalTable.head()
# Out:
#    Unnamed: 0      gameId TeamTwoWin  Team1P1  Team1P2  Team1P3  Team1P4  \
# 0           0  3882085921       Fail       96       29      360        6
# 1           0  3882103783        Win      876      875      427       68
# 2           0  3882119789       Fail      131       18      432      517
# 3           0  3882045523        Win       25       16       38      119
# 4           0  3882023571        Win       89      115       24      360
#
#    Team1P5  Team2P1  Team2P2  ...  \
# 0      112      203      157  ...
# 1      432      555       53  ...
# 2      106      526      120  ...
# 3       64      517       62  ...
# 4       30       25      105  ...
#
#                                          Team1P1SID  \
# 0   NmDSJ-OdlFsi_nJgd5RFTV5sg5mgKvFkj-y7cYlIo-HccG8
# 1   4E-sCfVJoizUFe0YzSsqi5DX023VVLi04K2hOOoK3uFC0EQ
# 2  auKoUXBD7TSW06WTZIwFWkCEwnUmwV_z4q2Zf8dwOFYtRQ50
# 3   NpS9WECNHkpxgS71T5LMTs0LsAGpq4mcIZA9EMJ652sJLNw
# 4  URMfCZVNNEylDxyxn8FsTRWPmH0cPtnHMgcybj_CMYMic4C3
#
#                                          Team1P2SID  \
# 0  PBUwkmJAZcX8gK7GLYQakQ8JNrYr2lu84rf59H5EC06E2Wg2
# 1   1_k4XrOQOaFH1SEQ0BPD8Xp_mMi_0OCW0rDjDqP0Tb5oZVk
# 2   jr6FtKPQ3rmp6s3srnxNF9Mtj2_Y-ZwIQ9xqBnP0JOgG2gQ
# 3   e32Nku_7zDVK10iyS9WPwzZ25-rH4JuyLl0UleOGf9tWa18
# 4   -RI4hwTi1KfglXwxo4cnswcbOS0bmRm_fZQzkEh-HHCRGoc
#
#                                          Team1P3SID  \
# 0   WmdibnD0VJBA7I4tWmbOiseQSN80caUabxR_OuC9lEia8bQ
# 1  N5G25tgJbExcn-ZC6bvKNMz8vXq8N63BEv765WXnIfa50a61
# 2   vTY4EPLBxbXhjOH9jTPs-O2t0gGMGO7GiDk_9yduqqPsZF0
# 3   TaXa0REyIryqVY0zgT5TVwn65OVWJUJ2kb4msaKqkZHTxDo
# 4   YfbajF4_sG_Xq_67rxDf8JxIwUVDZrTRvSyeKWBwwSAwA_8
#
#                                          Team1P4SID  \
# 0   Mf-eEVuziV1Iq5Q30XQGnXQAkAPgfZb2jkWc27mUSAkpRU0
# 1  auKoUXBD7TSW06WTZIwFWkCEwnUmwV_z4q2Zf8dwOFYtRQ50
# 2   TaXa0REyIryqVY0zgT5TVwn65OVWJUJ2kb4msaKqkZHTxDo
# 3   fHMgnBZbkya_QKj84XgzOZj4hdnJ7kMn4AM5yIahSB_zxJo
# 4  WafYrwhYhETAFR9LyHDlq4A57zXO6TF5_ptX49GFz45eD-me
#
#                                          Team1P5SID  \
# 0  tDNd50Dasl1_DU37xp1kira6gtKIGIeYHmekD1TaYbtBh_Xs
# 1   uoNDpzw1XQpIEKuHZhh7BBNsNtkLjUeWc54RJl4tz9ryMcU
# 2   rMOmJsCieKvVmJJOo6J-NuHzhtSrc8Pujbe5dTNd_whm4zI
# 3   3p_JofLwfwRnlhPhvhOcglHGQIWSi-hZQxgl5sGVj7Yd1UQ
# 4   CQgRwPicbM-ukSR6QcPOgQWGXm2Hmhbb0mzSr7gD4kCG2eM
#
#                                          Team2P1SID  \
# 0   4E-sCfVJoizUFe0YzSsqi5DX023VVLi04K2hOOoK3uFC0EQ
# 1   mLGCAAIoUtIM1J6cdPPJulAzptwr-yNapqMUf5UMIfLU8kQ
# 2   gjYXjMz7ndOKiAY0z14NhAfC-51yV96i9gi5BbPprJpo10I
# 3  auKoUXBD7TSW06WTZIwFWkCEwnUmwV_z4q2Zf8dwOFYtRQ50
# 4   hIJ27x5fhcRDBUy_5BV9sQJk_0u5-y4_c9qAUOdLjGZ98CI
#
#                                          Team2P2SID  \
# 0   1_k4XrOQOaFH1SEQ0BPD8Xp_mMi_0OCW0rDjDqP0Tb5oZVk
# 1   HcZ-wdbGo-KT6czGkCQl6-WoO-1hrE4iu5lNpZoeZxf7zw8
# 2   2HMiNABMdf1UfDEk1WJh_kx6iAvOWnlfkTQIYWgAmb4G1XA
# 3   a1EQKtujSdWhGi3xY08Kq0y7aPTda3gXwTCcuelRcqvTHyU
# 4  auKoUXBD7TSW06WTZIwFWkCEwnUmwV_z4q2Zf8dwOFYtRQ50
#
#                                          Team2P3SID  \
# 0  N5G25tgJbExcn-ZC6bvKNMz8vXq8N63BEv765WXnIfa50a61
# 1   a6IN6VX7OhoSrTO9XfYLkiq4IX4qQBOZdb1TkWMS6vj31rE
# 2   Pqz90M3Ow9jRyIhwYh6eLLCYvS9H5R67M48kzjzTw-D-7Pg
# 3   4dy_R8Bsn5K5i6N_rCXWRid2oVhOay9DChrziGdXsUgiLXs
# 4   6FIk2Gg67OkliUmVH-VR36HXiKwR9sm-X4k1oVeNmhO2c7Y
#
#                                          Team2P4SID  \
# 0  auKoUXBD7TSW06WTZIwFWkCEwnUmwV_z4q2Zf8dwOFYtRQ50
# 1   tT9AGjdAXWQgUypwrEUPGEIfR61NMBppYsECQQZMwlT-oO0
# 2   _XcNxsvPLFAVgbmUQxHp6U0EkBLxvN4_7zCJWjr7MdNarzQ
# 3  URMfCZVNNEylDxyxn8FsTRWPmH0cPtnHMgcybj_CMYMic4C3
# 4   xkvhucojMbpNKoDrbeHnPbarQm8vEWMa457hCpXGfANEIVk
#
#                                          Team2P5SID
# 0   Eb5Ia26ijVa_OKlnb8XghTayR5B0EVIxK0NlfPVWln60-Po
# 1   RxhN_jtdO5757rncs6EM3xVju3XlvTx9qVMKTDD0JkMt0A8
# 2  KX9Oq72Hs_ZdaqpPoailTdH42aWx8r9m2GVzF_46IzQVYT4X
# 3   CQgRwPicbM-ukSR6QcPOgQWGXm2Hmhbb0mzSr7gD4kCG2eM
# 4   TteAC3Wv_Sx2JmMd7rzseqOM_l1E6feZNWlhqznjrv670iQ
#
# [5 rows x 23 columns]

# %%
list(finalTable['Team2P1SID'])[0]
# Out:
# '4E-sCfVJoizUFe0YzSsqi5DX023VVLi04K2hOOoK3uFC0EQ'

# %%
finalTable2 = finalTable.head()
counter = 0
for index, row in finalTable2.iterrows():
    finalTable2["T1P1LP"] = p2[p2["summonerId"] == finalTable["Team1P1SID"][counter]]["leaguePoints"]
    counter = counter + 1
#finalTable2["T1P1LP"] = p2[p2["summonerId"] == finalTable["Team1P1SID"][5]]["leaguePoints"]
    
'''
try:
    finalTable2["T1P1LeaguePoints"] = p2[p2["summonerId"] == finalTable["Team1P1SID"]]["leaguePoints"]
except ValueError:
    pass
'''    
finalTable2
# Out:
# <ipython-input-27-b776681cb81c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finalTable2["T1P1LP"] = p2[p2["summonerId"] == finalTable["Team1P1SID"][counter]]["leaguePoints"]
#    Unnamed: 0      gameId TeamTwoWin  Team1P1  Team1P2  Team1P3  Team1P4  \
# 0           0  3882085921       Fail       96       29      360        6
# 1           0  3882103783        Win      876      875      427       68
# 2           0  3882119789       Fail      131       18      432      517
# 3           0  3882045523        Win       25       16       38      119
# 4           0  3882023571        Win       89      115       24      360
#
#    Team1P5  Team2P1  Team2P2  ...  \
# 0      112      203      157  ...
# 1      432      555       53  ...
# 2      106      526      120  ...
# 3       64      517       62  ...
# 4       30       25      105  ...
#
#                                          Team1P2SID  \
# 0  PBUwkmJAZcX8gK7GLYQakQ8JNrYr2lu84rf59H5EC06E2Wg2
# 1   1_k4XrOQOaFH1SEQ0BPD8Xp_mMi_0OCW0rDjDqP0Tb5oZVk
# 2   jr6FtKPQ3rmp6s3srnxNF9Mtj2_Y-ZwIQ9xqBnP0JOgG2gQ
# 3   e32Nku_7zDVK10iyS9WPwzZ25-rH4JuyLl0UleOGf9tWa18
# 4   -RI4hwTi1KfglXwxo4cnswcbOS0bmRm_fZQzkEh-HHCRGoc
#
#                                          Team1P3SID  \
# 0   WmdibnD0VJBA7I4tWmbOiseQSN80caUabxR_OuC9lEia8bQ
# 1  N5G25tgJbExcn-ZC6bvKNMz8vXq8N63BEv765WXnIfa50a61
# 2   vTY4EPLBxbXhjOH9jTPs-O2t0gGMGO7GiDk_9yduqqPsZF0
# 3   TaXa0REyIryqVY0zgT5TVwn65OVWJUJ2kb4msaKqkZHTxDo
# 4   YfbajF4_sG_Xq_67rxDf8JxIwUVDZrTRvSyeKWBwwSAwA_8
#
#                                          Team1P4SID  \
# 0   Mf-eEVuziV1Iq5Q30XQGnXQAkAPgfZb2jkWc27mUSAkpRU0
# 1  auKoUXBD7TSW06WTZIwFWkCEwnUmwV_z4q2Zf8dwOFYtRQ50
# 2   TaXa0REyIryqVY0zgT5TVwn65OVWJUJ2kb4msaKqkZHTxDo
# 3   fHMgnBZbkya_QKj84XgzOZj4hdnJ7kMn4AM5yIahSB_zxJo
# 4  WafYrwhYhETAFR9LyHDlq4A57zXO6TF5_ptX49GFz45eD-me
#
#                                          Team1P5SID  \
# 0  tDNd50Dasl1_DU37xp1kira6gtKIGIeYHmekD1TaYbtBh_Xs
# 1   uoNDpzw1XQpIEKuHZhh7BBNsNtkLjUeWc54RJl4tz9ryMcU
# 2   rMOmJsCieKvVmJJOo6J-NuHzhtSrc8Pujbe5dTNd_whm4zI
# 3   3p_JofLwfwRnlhPhvhOcglHGQIWSi-hZQxgl5sGVj7Yd1UQ
# 4   CQgRwPicbM-ukSR6QcPOgQWGXm2Hmhbb0mzSr7gD4kCG2eM
#
#                                          Team2P1SID  \
# 0   4E-sCfVJoizUFe0YzSsqi5DX023VVLi04K2hOOoK3uFC0EQ
# 1   mLGCAAIoUtIM1J6cdPPJulAzptwr-yNapqMUf5UMIfLU8kQ
# 2   gjYXjMz7ndOKiAY0z14NhAfC-51yV96i9gi5BbPprJpo10I
# 3  auKoUXBD7TSW06WTZIwFWkCEwnUmwV_z4q2Zf8dwOFYtRQ50
# 4   hIJ27x5fhcRDBUy_5BV9sQJk_0u5-y4_c9qAUOdLjGZ98CI
#
#                                          Team2P2SID  \
# 0   1_k4XrOQOaFH1SEQ0BPD8Xp_mMi_0OCW0rDjDqP0Tb5oZVk
# 1   HcZ-wdbGo-KT6czGkCQl6-WoO-1hrE4iu5lNpZoeZxf7zw8
# 2   2HMiNABMdf1UfDEk1WJh_kx6iAvOWnlfkTQIYWgAmb4G1XA
# 3   a1EQKtujSdWhGi3xY08Kq0y7aPTda3gXwTCcuelRcqvTHyU
# 4  auKoUXBD7TSW06WTZIwFWkCEwnUmwV_z4q2Zf8dwOFYtRQ50
#
#                                          Team2P3SID  \
# 0  N5G25tgJbExcn-ZC6bvKNMz8vXq8N63BEv765WXnIfa50a61
# 1   a6IN6VX7OhoSrTO9XfYLkiq4IX4qQBOZdb1TkWMS6vj31rE
# 2   Pqz90M3Ow9jRyIhwYh6eLLCYvS9H5R67M48kzjzTw-D-7Pg
# 3   4dy_R8Bsn5K5i6N_rCXWRid2oVhOay9DChrziGdXsUgiLXs
# 4   6FIk2Gg67OkliUmVH-VR36HXiKwR9sm-X4k1oVeNmhO2c7Y
#
#                                          Team2P4SID  \
# 0  auKoUXBD7TSW06WTZIwFWkCEwnUmwV_z4q2Zf8dwOFYtRQ50
# 1   tT9AGjdAXWQgUypwrEUPGEIfR61NMBppYsECQQZMwlT-oO0
# 2   _XcNxsvPLFAVgbmUQxHp6U0EkBLxvN4_7zCJWjr7MdNarzQ
# 3  URMfCZVNNEylDxyxn8FsTRWPmH0cPtnHMgcybj_CMYMic4C3
# 4   xkvhucojMbpNKoDrbeHnPbarQm8vEWMa457hCpXGfANEIVk
#
#                                          Team2P5SID T1P1LP
# 0   Eb5Ia26ijVa_OKlnb8XghTayR5B0EVIxK0NlfPVWln60-Po    NaN
# 1   RxhN_jtdO5757rncs6EM3xVju3XlvTx9qVMKTDD0JkMt0A8    NaN
# 2  KX9Oq72Hs_ZdaqpPoailTdH42aWx8r9m2GVzF_46IzQVYT4X    NaN
# 3   CQgRwPicbM-ukSR6QcPOgQWGXm2Hmhbb0mzSr7gD4kCG2eM    NaN
# 4   TteAC3Wv_Sx2JmMd7rzseqOM_l1E6feZNWlhqznjrv670iQ    NaN
#
# [5 rows x 24 columns]

# %%
finalTable2 = pd.read_csv("matchesV6.csv")

# %%
p2.head()
# Out:
#    Unnamed: 0                                         summonerId summonerName  \
# 0           0    TzZVECncJS4jMEZZgif9PBP81-8RP_ADx2Z4_VJ5b2Sz5Yk         AnDa
# 1           1   auKoUXBD7TSW06WTZIwFWkCEwnUmwV_z4q2Zf8dwOFYtRQ50       Lu0 Ye
# 2           2    e32Nku_7zDVK10iyS9WPwzZ25-rH4JuyLl0UleOGf9tWa18       Geiger
# 3           3  bGQiRA7YtuPH1MKc0j8AsCRJzEiFXiyRqbqTQolmAM3uAr...     CLG Finn
# 4           4  MhIDAfj-jbhXiVLeFKTmQuP4VCo-tBp0EEnXbPopyXE3of...   poome iwnl
#
#    leaguePoints  wins  losses        rank  \
# 0          1195   251     210  Challenger
# 1           504   117     104  Challenger
# 2           539   417     399  Challenger
# 3           916   151     122  Challenger
# 4           748   106      77  Challenger
#
#                                            accountId
# 0     l8zV1k9mOLsZ33xlZ-hJff0yCpVLYgbCPJydyjheV5-tvg
# 1  IARqY_Tf4CtXHJ3axYeNPndQ5Cv61pg50k8ygbrX1GpMXr...
# 2    dHLOdwBkOa0vRuST-qg9r9B2dIvHp5SIIhYneOdgGVE_q4s
# 3  QtANCstlA3rzMDu2tauh7D_d9xWscI5nMTwWvMvqKElBC1...
# 4  iga5_2jGUG5QKwNVtox_nSQ8V0KBVLuQkvEVv1sUU05WST...

# %%
int(p2.loc[p2["summonerId"] == "TzZVECncJS4jMEZZgif9PBP81-8RP_ADx2Z4_VJ5b2Sz5Yk"]["leaguePoints"])
# Out:
# 1113

# %%
T1P1SID = finalTable2["Team1P1SID"].to_list()
T1P2SID = finalTable2["Team1P2SID"].to_list()
T1P3SID = finalTable2["Team1P3SID"].to_list()
T1P4SID = finalTable2["Team1P4SID"].to_list()
T1P5SID = finalTable2["Team1P5SID"].to_list()
T2P1SID = finalTable2["Team2P1SID"].to_list()
T2P2SID = finalTable2["Team2P2SID"].to_list()
T2P3SID = finalTable2["Team2P3SID"].to_list()
T2P4SID = finalTable2["Team2P4SID"].to_list()
T2P5SID = finalTable2["Team2P5SID"].to_list()

lp1,lp2,lp3,lp4,lp5,lp6,lp7,lp8,lp9,lp10 = [],[],[],[],[],[],[],[],[],[]
lp11,lp12,lp13,lp14,lp15,lp16,lp17,lp18,lp19,lp20 = [],[],[],[],[],[],[],[],[],[]

for sid in T1P1SID:
    try:
        #lp1.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        #print(int(p2.loc[p2["summonerId"] == sid]["championPoints"]))
        #print(p2.loc[p2["summonerId"] == sid]["leaguePoints"])
        lp1.append(int(p2.loc[p2["summonerId"] == sid]["leaguePoints"]))
    except TypeError:
        lp1.append(200)
        
for sid in T1P2SID:
    try:
        #lp2.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        lp2.append(int(p2.loc[p2["summonerId"] == sid]["leaguePoints"]))
    except TypeError:
        lp2.append(200)
        
for sid in T1P3SID:
    try:
        #lp3.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        lp3.append(int(p2.loc[p2["summonerId"] == sid]["leaguePoints"]))
    except TypeError:
        lp3.append(200)
        
for sid in T1P4SID:
    try:
        #lp4.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        lp4.append(int(p2.loc[p2["summonerId"] == sid]["leaguePoints"]))
    except TypeError:
        lp4.append(200)
        
for sid in T1P5SID:
    try:
        #lp5.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        lp5.append(int(p2.loc[p2["summonerId"] == sid]["leaguePoints"]))
    except TypeError:
        lp5.append(200)

        
        
        
for sid in T2P1SID:
    try:
        #lp6.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        lp6.append(int(p2.loc[p2["summonerId"] == sid]["leaguePoints"]))
    except TypeError:
        lp6.append(200)
        
for sid in T2P2SID:
    try:
        #lp7.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        lp7.append(int(p2.loc[p2["summonerId"] == sid]["leaguePoints"]))
    except TypeError:
        lp7.append(200)

for sid in T2P3SID:
    try:
        #lp8.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        lp8.append(int(p2.loc[p2["summonerId"] == sid]["leaguePoints"]))
    except TypeError:
        lp8.append(200)

for sid in T2P4SID:
    try:
        #lp9.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        lp9.append(int(p2.loc[p2["summonerId"] == sid]["leaguePoints"]))
    except TypeError:
        lp9.append(200)

for sid in T2P5SID:
    try:
        #lp10.append(p2[p2["summonerId"] == sid]["leaguePoints"].loc[1])
        lp10.append(int(p2.loc[p2["summonerId"] == sid]["leaguePoints"]))
    except TypeError:
        lp10.append(200)
        
        
finalTable2["T1P1LP"] = lp1
finalTable2["T1P2LP"] = lp2
finalTable2["T1P3LP"] = lp3
finalTable2["T1P4LP"] = lp4
finalTable2["T1P5LP"] = lp5
finalTable2["T2P1LP"] = lp6
finalTable2["T2P2LP"] = lp7
finalTable2["T2P3LP"] = lp8
finalTable2["T2P4LP"] = lp9
finalTable2["T2P5LP"] = lp10
'''
finalTable2["T1P1LP1"] = lp11
finalTable2["T1P2LP1"] = lp12
finalTable2["T1P3LP1"] = lp13
finalTable2["T1P4LP1"] = lp14
finalTable2["T1P5LP1"] = lp15
finalTable2["T2P1LP1"] = lp16
finalTable2["T2P2LP1"] = lp17
finalTable2["T2P3LP1"] = lp18
finalTable2["T2P4LP1"] = lp19
finalTable2["T2P5LP1"] = lp20
'''
finalTable2
# Out:
#      Unnamed: 0      gameId TeamTwoWin  Team1P1  Team1P2  Team1P3  Team1P4  \
# 0             0  3888738788        Win       74       68      432      203
# 1             0  3888177313        Win      412       50       54      360
# 2             0  3888230671       Fail       76       55      350       38
# 3             0  3888156066       Fail      145       41       68       57
# 4             0  3888131553       Fail        4      222      117       64
# ..          ...         ...        ...      ...      ...      ...      ...
# 857         351  3879694279       Fail      360       77      526      131
# 858         352  3879565652        Win      203       91        3       84
# 859         353  3879590242       Fail      157       53       28       92
# 860         354  3879517949        Win      555       18      777      887
# 861         355  3879515068       Fail       40       41      203        8
#
#      Team1P5  Team2P1  Team2P2  ...  T1P1LP  T1P2LP  T1P3LP T1P4LP T1P5LP  \
# 0        222      234      145  ...     200     363     388    637    547
# 1        104      202       89  ...     200     200     200    200    200
# 2        266      117      157  ...     200     200     200    200    585
# 3         24      107      236  ...     200     200     200    200    200
# 4        150        2      145  ...     200     200     200    200    585
# ..       ...      ...      ...  ...     ...     ...     ...    ...    ...
# 857      164       24       18  ...     525     564     516    200    552
# 858      157       39      222  ...     441     200     484    377    653
# 859      145       18       89  ...     616     569     600    508    480
# 860      245      157      876  ...     948     480     476    260    441
# 861      145      555       39  ...     574     844     200    494    200
#
#     T2P1LP T2P2LP T2P3LP T2P4LP T2P5LP
# 0      451    410    200    295    585
# 1      200    200    200    200    585
# 2      200    200    200    200    200
# 3      200    200    200    200    585
# 4      200    200    200    200    200
# ..     ...    ...    ...    ...    ...
# 857    844    331    282    442    200
# 858    844    750    624    200    448
# 859    750    404    568    844    441
# 860    653    494    718    547    844
# 861    484    200    534    802    200
#
# [862 rows x 53 columns]

# %%
finalTable2.shape
lp2
# Out:
# [363,
#  200,
#  200,
#  200,
#  200,
#  200,
#  499,
#  504,
#  585,
#  471,
#  200,
#  273,
#  318,
#  442,
#  408,
#  200,
#  583,
#  638,
#  628,
#  200,
#  511,
#  725,
#  296,
#  332,
#  585,
#  200,
#  484,
#  560,
#  585,
#  200,
#  200,
#  255,
#  200,
#  200,
#  585,
#  613,
#  299,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  282,
#  200,
#  200,
#  200,
#  200,
#  388,
#  200,
#  442,
#  335,
#  200,
#  200,
#  200,
#  200,
#  123,
#  200,
#  508,
#  349,
#  654,
#  833,
#  870,
#  200,
#  431,
#  411,
#  585,
#  200,
#  200,
#  752,
#  200,
#  200,
#  268,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  353,
#  200,
#  394,
#  200,
#  729,
#  729,
#  693,
#  450,
#  395,
#  1209,
#  200,
#  200,
#  729,
#  421,
#  296,
#  422,
#  578,
#  639,
#  352,
#  639,
#  431,
#  200,
#  200,
#  789,
#  908,
#  1018,
#  332,
#  200,
#  200,
#  729,
#  200,
#  200,
#  200,
#  802,
#  200,
#  465,
#  200,
#  620,
#  948,
#  232,
#  200,
#  729,
#  200,
#  833,
#  256,
#  200,
#  200,
#  200,
#  200,
#  200,
#  530,
#  360,
#  552,
#  796,
#  784,
#  392,
#  816,
#  200,
#  415,
#  729,
#  200,
#  441,
#  200,
#  410,
#  200,
#  729,
#  380,
#  200,
#  300,
#  322,
#  200,
#  200,
#  200,
#  729,
#  415,
#  200,
#  200,
#  200,
#  224,
#  238,
#  200,
#  729,
#  262,
#  200,
#  200,
#  238,
#  729,
#  816,
#  200,
#  200,
#  537,
#  1306,
#  322,
#  441,
#  270,
#  200,
#  200,
#  335,
#  200,
#  200,
#  1114,
#  1025,
#  1052,
#  1570,
#  1025,
#  765,
#  1087,
#  1052,
#  908,
#  508,
#  600,
#  1025,
#  585,
#  1109,
#  775,
#  1006,
#  200,
#  585,
#  585,
#  1025,
#  582,
#  1025,
#  779,
#  200,
#  738,
#  1072,
#  277,
#  1025,
#  621,
#  1010,
#  558,
#  253,
#  200,
#  546,
#  793,
#  1148,
#  438,
#  600,
#  886,
#  400,
#  872,
#  200,
#  200,
#  200,
#  876,
#  586,
#  685,
#  876,
#  788,
#  652,
#  958,
#  200,
#  200,
#  793,
#  836,
#  300,
#  613,
#  1362,
#  1025,
#  200,
#  323,
#  886,
#  1109,
#  200,
#  200,
#  1025,
#  1025,
#  244,
#  1114,
#  302,
#  1306,
#  353,
#  1306,
#  872,
#  457,
#  895,
#  605,
#  200,
#  764,
#  370,
#  1125,
#  367,
#  421,
#  563,
#  266,
#  718,
#  465,
#  607,
#  1265,
#  635,
#  200,
#  200,
#  480,
#  1025,
#  685,
#  458,
#  697,
#  475,
#  363,
#  1068,
#  1087,
#  1413,
#  761,
#  958,
#  958,
#  844,
#  680,
#  733,
#  595,
#  480,
#  986,
#  601,
#  986,
#  1044,
#  480,
#  1025,
#  1052,
#  1042,
#  314,
#  351,
#  584,
#  1025,
#  765,
#  816,
#  600,
#  908,
#  720,
#  530,
#  586,
#  1005,
#  810,
#  1005,
#  520,
#  986,
#  895,
#  436,
#  685,
#  720,
#  1114,
#  725,
#  568,
#  522,
#  986,
#  752,
#  458,
#  986,
#  747,
#  591,
#  1010,
#  872,
#  595,
#  569,
#  1306,
#  1006,
#  685,
#  986,
#  703,
#  900,
#  784,
#  876,
#  816,
#  663,
#  885,
#  870,
#  842,
#  541,
#  986,
#  543,
#  585,
#  1025,
#  986,
#  725,
#  789,
#  639,
#  646,
#  200,
#  811,
#  703,
#  609,
#  870,
#  986,
#  634,
#  689,
#  796,
#  779,
#  779,
#  415,
#  200,
#  733,
#  454,
#  395,
#  986,
#  986,
#  789,
#  743,
#  1281,
#  1306,
#  876,
#  451,
#  583,
#  1410,
#  200,
#  390,
#  504,
#  605,
#  582,
#  779,
#  505,
#  233,
#  505,
#  638,
#  423,
#  200,
#  575,
#  588,
#  600,
#  312,
#  375,
#  304,
#  693,
#  1072,
#  582,
#  200,
#  582,
#  200,
#  200,
#  344,
#  476,
#  400,
#  353,
#  408,
#  277,
#  582,
#  631,
#  200,
#  200,
#  235,
#  200,
#  620,
#  377,
#  389,
#  680,
#  573,
#  615,
#  537,
#  845,
#  608,
#  573,
#  200,
#  200,
#  200,
#  352,
#  529,
#  529,
#  530,
#  385,
#  573,
#  573,
#  200,
#  200,
#  595,
#  573,
#  493,
#  586,
#  608,
#  563,
#  572,
#  572,
#  200,
#  200,
#  200,
#  200,
#  718,
#  840,
#  252,
#  353,
#  461,
#  200,
#  200,
#  318,
#  414,
#  277,
#  277,
#  200,
#  335,
#  1281,
#  329,
#  457,
#  1052,
#  414,
#  656,
#  200,
#  499,
#  250,
#  566,
#  200,
#  513,
#  686,
#  573,
#  573,
#  200,
#  473,
#  200,
#  573,
#  200,
#  624,
#  583,
#  200,
#  200,
#  200,
#  430,
#  200,
#  464,
#  200,
#  200,
#  231,
#  200,
#  416,
#  509,
#  200,
#  443,
#  200,
#  1010,
#  238,
#  907,
#  585,
#  640,
#  1018,
#  200,
#  269,
#  356,
#  355,
#  535,
#  355,
#  579,
#  458,
#  621,
#  480,
#  454,
#  509,
#  331,
#  329,
#  594,
#  480,
#  414,
#  844,
#  200,
#  761,
#  200,
#  431,
#  415,
#  455,
#  256,
#  358,
#  582,
#  537,
#  200,
#  323,
#  832,
#  200,
#  400,
#  231,
#  200,
#  200,
#  1044,
#  450,
#  563,
#  525,
#  1018,
#  200,
#  650,
#  321,
#  713,
#  650,
#  233,
#  650,
#  200,
#  458,
#  200,
#  585,
#  811,
#  200,
#  422,
#  370,
#  340,
#  549,
#  308,
#  200,
#  316,
#  200,
#  652,
#  650,
#  200,
#  242,
#  744,
#  200,
#  200,
#  650,
#  525,
#  453,
#  811,
#  811,
#  200,
#  200,
#  200,
#  200,
#  1209,
#  845,
#  948,
#  1109,
#  200,
#  1004,
#  784,
#  1072,
#  200,
#  948,
#  811,
#  326,
#  948,
#  948,
#  200,
#  541,
#  200,
#  200,
#  586,
#  762,
#  670,
#  454,
#  1052,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  269,
#  796,
#  200,
#  738,
#  734,
#  200,
#  200,
#  200,
#  200,
#  701,
#  200,
#  711,
#  658,
#  1048,
#  415,
#  948,
#  487,
#  200,
#  302,
#  200,
#  200,
#  411,
#  200,
#  200,
#  316,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  1114,
#  685,
#  200,
#  200,
#  200,
#  1018,
#  802,
#  605,
#  200,
#  200,
#  948,
#  200,
#  560,
#  1030,
#  635,
#  1052,
#  395,
#  395,
#  305,
#  618,
#  493,
#  429,
#  300,
#  624,
#  304,
#  420,
#  302,
#  569,
#  316,
#  754,
#  441,
#  200,
#  454,
#  365,
#  560,
#  353,
#  200,
#  461,
#  560,
#  886,
#  522,
#  560,
#  441,
#  200,
#  738,
#  200,
#  367,
#  560,
#  1109,
#  562,
#  560,
#  587,
#  1410,
#  234,
#  224,
#  585,
#  1072,
#  250,
#  400,
#  811,
#  262,
#  200,
#  200,
#  200,
#  200,
#  200,
#  431,
#  353,
#  566,
#  477,
#  200,
#  200,
#  583,
#  729,
#  262,
#  560,
#  200,
#  836,
#  601,
#  816,
#  200,
#  685,
#  601,
#  560,
#  481,
#  537,
#  628,
#  1148,
#  535,
#  886,
#  572,
#  624,
#  302,
#  309,
#  560,
#  200,
#  278,
#  471,
#  304,
#  477,
#  840,
#  473,
#  200,
#  200,
#  326,
#  200,
#  200,
#  200,
#  560,
#  656,
#  560,
#  624,
#  683,
#  948,
#  620,
#  1005,
#  886,
#  438,
#  779,
#  802,
#  200,
#  238,
#  640,
#  870,
#  737,
#  557,
#  450,
#  575,
#  483,
#  842,
#  457,
#  844,
#  652,
#  743,
#  685,
#  395,
#  1209,
#  1001,
#  680,
#  547,
#  482,
#  1005,
#  508,
#  480,
#  1005,
#  948,
#  844,
#  802,
#  1025,
#  1052,
#  656,
#  656,
#  693,
#  816,
#  584,
#  725,
#  1005,
#  720,
#  810,
#  759,
#  492,
#  321,
#  789,
#  594,
#  549,
#  844,
#  844,
#  568,
#  652,
#  844,
#  1595,
#  631,
#  332,
#  844,
#  301,
#  1072,
#  844,
#  986,
#  534,
#  616,
#  870,
#  588,
#  844,
#  729,
#  200,
#  844,
#  796,
#  571,
#  422,
#  425,
#  686,
#  588,
#  608,
#  569,
#  516,
#  438,
#  461,
#  654,
#  573,
#  811,
#  693,
#  200,
#  296,
#  231,
#  587,
#  725,
#  564,
#  200,
#  569,
#  480,
#  844]

# %%
#Works
p2[p2["summonerId"] == "auKoUXBD7TSW06WTZIwFWkCEwnUmwV_z4q2Zf8dwOFYtRQ50"]["leaguePoints"]
# Out:
# 1    504
# Name: leaguePoints, dtype: int64

# %%
T1P1CID = finalTable2["Team1P1"].to_list()
T1P2CID = finalTable2["Team1P2"].to_list()
T1P3CID = finalTable2["Team1P3"].to_list()
T1P4CID = finalTable2["Team1P4"].to_list()
T1P5CID = finalTable2["Team1P5"].to_list()
T2P1CID = finalTable2["Team2P1"].to_list()
T2P2CID = finalTable2["Team2P2"].to_list()
T2P3CID = finalTable2["Team2P3"].to_list()
T2P4CID = finalTable2["Team2P4"].to_list()
T2P5CID = finalTable2["Team2P5"].to_list()


cm1,cm2,cm3,cm4,cm5,cm6,cm7,cm8,cm9,cm10 = [],[],[],[],[],[],[],[],[],[]

counter = 0
for sid in T1P1SID:
    try:
        cm1.append(int(mastery.loc[(mastery["championId"] == T1P1CID[counter]) & (mastery["summonerId"] == sid)]["championPoints"]))
    except KeyError:
        cm1.append(0)
    except TypeError:
        cm1.append(1)
    counter = counter + 1
    
counter = 0
for sid in T1P2SID:
    try:
        cm2.append(int(mastery.loc[(mastery["championId"] == T1P2CID[counter]) & (mastery["summonerId"] == sid)]["championPoints"]))
    except TypeError:
        cm2.append(1)
    counter = counter + 1
    
counter = 0        
for sid in T1P3SID:
    try:
        cm3.append(int(mastery.loc[(mastery["championId"] == T1P3CID[counter]) & (mastery["summonerId"] == sid)]["championPoints"]))
    except TypeError:
        cm3.append(1)
    counter = counter + 1

counter = 0
for sid in T1P4SID:
    try:
        cm4.append(int(mastery.loc[(mastery["championId"] == T1P4CID[counter]) & (mastery["summonerId"] == sid)]["championPoints"]))
    except TypeError:
        cm4.append(1)
    counter = counter + 1
        
counter = 0
for sid in T1P5SID:
    try:
        cm5.append(int(mastery.loc[(mastery["championId"] == T1P5CID[counter]) & (mastery["summonerId"] == sid)]["championPoints"]))
    except TypeError:
        cm5.append(1)
    counter = counter + 1

        
        
counter = 0        
for sid in T2P1SID:
    try:
        cm6.append(int(mastery.loc[(mastery["championId"] == T2P1CID[counter]) & \
                                   (mastery["summonerId"] == sid)]["championPoints"]))
    except TypeError:
        cm6.append(1)
    counter = counter + 1
    
counter = 0        
for sid in T2P2SID:
    try:
        cm7.append(int(mastery.loc[(mastery["championId"] == T2P2CID[counter]) & \
                                   (mastery["summonerId"] == sid)]["championPoints"]))
    except TypeError:
        cm7.append(1)
    counter = counter + 1
    
counter = 0
for sid in T2P3SID:
    try:
        cm8.append(int(mastery.loc[(mastery["championId"] == T2P3CID[counter]) & \
                                   (mastery["summonerId"] == sid)]["championPoints"]))
    except TypeError:
        cm8.append(1)
    counter = counter + 1
    
counter = 0
for sid in T2P4SID:
    try:
        cm9.append(int(mastery.loc[(mastery["championId"] == T2P4CID[counter]) & \
                                   (mastery["summonerId"] == sid)]["championPoints"]))
    except TypeError:
        cm9.append(1)
    counter = counter + 1
    
counter = 0
for sid in T2P5SID:
    try:
        cm10.append(int(mastery.loc[(mastery["championId"] == T2P5CID[counter]) & \
                                   (mastery["summonerId"] == sid)]["championPoints"]))
    except TypeError:
        cm10.append(1)
    counter = counter + 1
        
        
finalTable2["T1P1CM"] = cm1
finalTable2["T1P2CM"] = cm2
finalTable2["T1P3CM"] = cm3
finalTable2["T1P4CM"] = cm4
finalTable2["T1P5CM"] = cm5
finalTable2["T2P1CM"] = cm6
finalTable2["T2P2CM"] = cm7
finalTable2["T2P3CM"] = cm8
finalTable2["T2P4CM"] = cm9
finalTable2["T2P5CM"] = cm10
finalTable2
# Out:
#      Unnamed: 0      gameId TeamTwoWin  Team1P1  Team1P2  Team1P3  Team1P4  \
# 0             0  3888738788        Win       74       68      432      203
# 1             0  3888177313        Win      412       50       54      360
# 2             0  3888230671       Fail       76       55      350       38
# 3             0  3888156066       Fail      145       41       68       57
# 4             0  3888131553       Fail        4      222      117       64
# ..          ...         ...        ...      ...      ...      ...      ...
# 857         351  3879694279       Fail      360       77      526      131
# 858         352  3879565652        Win      203       91        3       84
# 859         353  3879590242       Fail      157       53       28       92
# 860         354  3879517949        Win      555       18      777      887
# 861         355  3879515068       Fail       40       41      203        8
#
#      Team1P5  Team2P1  Team2P2  ...  T1P1LP  T1P2LP  T1P3LP T1P4LP T1P5LP  \
# 0        222      234      145  ...     200     200     200    200    200
# 1        104      202       89  ...     200     200     200    200    200
# 2        266      117      157  ...     200     200     200    200    585
# 3         24      107      236  ...     200     200     200    200    200
# 4        150        2      145  ...     200     200     200    200    585
# ..       ...      ...      ...  ...     ...     ...     ...    ...    ...
# 857      164       24       18  ...     200     200     200    200    200
# 858      157       39      222  ...     200     200     200    200    200
# 859      145       18       89  ...     200     200     200    200    200
# 860      245      157      876  ...     200     200     200    200    200
# 861      145      555       39  ...     200     200     200    200    200
#
#     T2P1LP T2P2LP T2P3LP T2P4LP T2P5LP
# 0      200    200    200    200    585
# 1      200    200    200    200    585
# 2      200    200    200    200    200
# 3      200    200    200    200    585
# 4      200    200    200    200    200
# ..     ...    ...    ...    ...    ...
# 857    200    200    200    200    200
# 858    200    200    200    200    200
# 859    200    200    200    200    200
# 860    200    200    200    200    200
# 861    200    200    200    200    200
#
# [862 rows x 53 columns]

# %%
#WORKS
int(mastery.loc[(mastery["championId"] == 68) & (mastery["summonerId"] == "auKoUXBD7TSW06WTZIwFWkCEwnUmwV_z4q2Zf8dwOFYtRQ50")]["championPoints"])
# Out:
# 401

# %%
#Doesn't work yet
#np.where(mastery(mastery["championId"] == 68) & (mastery["summonerId"] == "auKoUXBD7TSW06WTZIwFWkCEwnUmwV_z4q2Zf8dwOFYtRQ50"))

# %%
finalTable2.to_csv('CMandLP4.csv')
